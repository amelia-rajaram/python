# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Cleaning

# %%
file_path = '/Users/amelia/Documents/python_project/python_project_final_edit.xlsx'

try:
    df = pd.read_excel(file_path, sheet_name='Sheet1')
    display(df.head())  # Display the first few rows of the sheet
except Exception as e:
    print(f"Error reading the Excel file: {e}")

try:
    # Fill NaN values for categorical columns with 'Unknown' and for numerical columns with the median
    for column in df.columns:
        if df[column].dtype == 'object':
            df[column].fillna('Unknown', inplace=True)
        else:
            df[column].fillna(df[column].median(), inplace=True)

    # Cleaned data
    print("Cleaned Data:")
    display(df.head())

    # Save the cleaned data to a new Excel file
    cleaned_file_path = '/Users/amelia/Documents/python_project/cleaned_python_project_final_edit.xlsx'
    df.to_excel(cleaned_file_path, index=False)
    print(f"Cleaned data saved to {cleaned_file_path}")

except FileNotFoundError:
    print(f"The file at path {file_path} was not found. Please check the file path and try again.")
except Exception as e:
    print(f"Error cleaning the data: {e}")
# Out:
#      age gender     city country          occupation      style_preference  \
# 0  55-64     NB  Nairobi      KE  Full-time employed      Classic, Elegant
# 1  25-34      M   Athens      GR  Full-time employed       Formal, Vintage
# 2  25-34      M    Seoul      KR  Full-time employed      Casual, Athletic
# 3  45-54      M     Rome      IT  Full-time employed  Athletic, Minimalist
# 4  55-64      M     Lima      PE  Full-time employed      Bohemian, Casual
#
#                  clothing_types                  discovery_method  \
# 0  Casual wear, Business attire       Social media, Fashion blogs
# 1       Sportswear, Casual wear  Social media, Friends and family
# 2       Sportswear, Casual wear  Social media, Friends and family
# 3      Casual wear, Ethnic wear  Fashion blogs, Fashion magazines
# 4      Formal wear, Casual wear       Social media, Online forums
#
#                      shopping_venues  knowledge_on_sustainable_fashion  \
# 0  Online retailers, Physical stores                                 4
# 1  Physical stores, Online boutiques                                 4
# 2  Physical stores, Online boutiques                                 4
# 3  Online retailers, Physical stores                                 6
# 4  Physical stores, Online retailers                                 6
#
#    environmental_awareness  eco-friendly_actions  \
# 0                        3                     0
# 1                        5                     0
# 2                        3                     0
# 3                        5                     1
# 4                        6                     1
#
#    importance_of_sustainability  \
# 0                             6
# 1                             6
# 2                             7
# 3                             5
# 4                             5
#
#    sustainability_factors:_use_of_eco-friendly_materials  \
# 0                                                  5
# 1                                                  7
# 2                                                  6
# 3                                                  5
# 4                                                  5
#
#    sustainability_factors:_ethical_production_and_labor_practices  \
# 0                                                  5
# 1                                                  7
# 2                                                  6
# 3                                                  5
# 4                                                  5
#
#    sustainability_factors:_reduction_of_carbon_footprint  \
# 0                                                  5
# 1                                                  7
# 2                                                  6
# 3                                                  6
# 4                                                  5
#
#    sustainability_factors:_minimal_water_usage  \
# 0                                            5
# 1                                            7
# 2                                            6
# 3                                            6
# 4                                            5
#
#    sustainability_factors:_transparency_in_the_supply_chain  \
# 0                                                  5
# 1                                                  7
# 2                                                  6
# 3                                                  5
# 4                                                  5
#
#    sustainability_factors:_supporting_local_and_artisanal_brands  \
# 0                                                  5
# 1                                                  7
# 2                                                  6
# 3                                                  6
# 4                                                  5
#
#    willingness_to_pay_more sustainable_shopping_frequency  \
# 0                        0                            NaN
# 1                        0                         Rarely
# 2                        1                         Rarely
# 3                        1                     Frequently
# 4                        1                      Sometimes
#
#   donation/recycling_habits repair_habits  influence_of_sustainability_labels  \
# 0                Frequently        Rarely                                   1
# 1                Frequently        Rarely                                   1
# 2                Frequently        Rarely                                   1
# 3                Frequently         Often                                   1
# 4              Occasionally     Sometimes                                   0
#
#    sustainable_material_preference  brand_choice_based_on_ethical_practices  \
# 0                                7                                        1
# 1                                6                                        1
# 2                                6                                        1
# 3                                5                                        1
# 4                                5                                        0
#
#    knowledge_of_sustainable_brands known_sustainable_brands  \
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2                              1.0                      NaN
# 3                              1.0            ASOS, Topshop
# 4                              0.0        Zara, Pull & Bear
#
#    fashion-lifestyle_alignment  use_of_styling_apps  \
# 0                          NaN                    1
# 1                          6.0                    1
# 2                          7.0                    0
# 3                          6.0                    1
# 4                          5.0                    0
#
#    satisfaction_with_styling_apps  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             6.0
#
#                     desired_clothing_recommendations  \
# 0                                                NaN
# 1               Fashion trends, Seasonal suggestions
# 2  Sustainable clothing options, Fashion trends, ...
# 3               Fashion trends, Seasonal suggestions
# 4                 Casual styles, Comfortable designs
#
#    interest_in_visual_search  \
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
#
#                                     features_for_app  \
# 0  Price range, Brand preferences, Sustainable br...
# 1  Price range, Brand preferences, Sustainable br...
# 2  Price range, Brand preferences, Sustainable br...
# 3  Brand preferences, Price range, User-generated...
# 4  Brand preferences, Sustainable certifications,...
#
#               features_for_app.1
# 0            Discounts and sales
# 1            Discounts and sales
# 2            Discounts and sales
# 3     Athletic and modern fusion
# 4  Need more comfortable options
# Cleaned Data:
#      age gender     city country          occupation      style_preference  \
# 0  55-64     NB  Nairobi      KE  Full-time employed      Classic, Elegant
# 1  25-34      M   Athens      GR  Full-time employed       Formal, Vintage
# 2  25-34      M    Seoul      KR  Full-time employed      Casual, Athletic
# 3  45-54      M     Rome      IT  Full-time employed  Athletic, Minimalist
# 4  55-64      M     Lima      PE  Full-time employed      Bohemian, Casual
#
#                  clothing_types                  discovery_method  \
# 0  Casual wear, Business attire       Social media, Fashion blogs
# 1       Sportswear, Casual wear  Social media, Friends and family
# 2       Sportswear, Casual wear  Social media, Friends and family
# 3      Casual wear, Ethnic wear  Fashion blogs, Fashion magazines
# 4      Formal wear, Casual wear       Social media, Online forums
#
#                      shopping_venues  knowledge_on_sustainable_fashion  \
# 0  Online retailers, Physical stores                                 4
# 1  Physical stores, Online boutiques                                 4
# 2  Physical stores, Online boutiques                                 4
# 3  Online retailers, Physical stores                                 6
# 4  Physical stores, Online retailers                                 6
#
#    environmental_awareness  eco-friendly_actions  \
# 0                        3                     0
# 1                        5                     0
# 2                        3                     0
# 3                        5                     1
# 4                        6                     1
#
#    importance_of_sustainability  \
# 0                             6
# 1                             6
# 2                             7
# 3                             5
# 4                             5
#
#    sustainability_factors:_use_of_eco-friendly_materials  \
# 0                                                  5
# 1                                                  7
# 2                                                  6
# 3                                                  5
# 4                                                  5
#
#    sustainability_factors:_ethical_production_and_labor_practices  \
# 0                                                  5
# 1                                                  7
# 2                                                  6
# 3                                                  5
# 4                                                  5
#
#    sustainability_factors:_reduction_of_carbon_footprint  \
# 0                                                  5
# 1                                                  7
# 2                                                  6
# 3                                                  6
# 4                                                  5
#
#    sustainability_factors:_minimal_water_usage  \
# 0                                            5
# 1                                            7
# 2                                            6
# 3                                            6
# 4                                            5
#
#    sustainability_factors:_transparency_in_the_supply_chain  \
# 0                                                  5
# 1                                                  7
# 2                                                  6
# 3                                                  5
# 4                                                  5
#
#    sustainability_factors:_supporting_local_and_artisanal_brands  \
# 0                                                  5
# 1                                                  7
# 2                                                  6
# 3                                                  6
# 4                                                  5
#
#    willingness_to_pay_more sustainable_shopping_frequency  \
# 0                        0                        Unknown
# 1                        0                         Rarely
# 2                        1                         Rarely
# 3                        1                     Frequently
# 4                        1                      Sometimes
#
#   donation/recycling_habits repair_habits  influence_of_sustainability_labels  \
# 0                Frequently        Rarely                                   1
# 1                Frequently        Rarely                                   1
# 2                Frequently        Rarely                                   1
# 3                Frequently         Often                                   1
# 4              Occasionally     Sometimes                                   0
#
#    sustainable_material_preference  brand_choice_based_on_ethical_practices  \
# 0                                7                                        1
# 1                                6                                        1
# 2                                6                                        1
# 3                                5                                        1
# 4                                5                                        0
#
#    knowledge_of_sustainable_brands known_sustainable_brands  \
# 0                              1.0                  Unknown
# 1                              1.0                  Unknown
# 2                              1.0                  Unknown
# 3                              1.0            ASOS, Topshop
# 4                              0.0        Zara, Pull & Bear
#
#    fashion-lifestyle_alignment  use_of_styling_apps  \
# 0                          5.0                    1
# 1                          6.0                    1
# 2                          7.0                    0
# 3                          6.0                    1
# 4                          5.0                    0
#
#    satisfaction_with_styling_apps  \
# 0                             5.0
# 1                             5.0
# 2                             5.0
# 3                             5.0
# 4                             6.0
#
#                     desired_clothing_recommendations  \
# 0                                            Unknown
# 1               Fashion trends, Seasonal suggestions
# 2  Sustainable clothing options, Fashion trends, ...
# 3               Fashion trends, Seasonal suggestions
# 4                 Casual styles, Comfortable designs
#
#    interest_in_visual_search  \
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
#
#                                     features_for_app  \
# 0  Price range, Brand preferences, Sustainable br...
# 1  Price range, Brand preferences, Sustainable br...
# 2  Price range, Brand preferences, Sustainable br...
# 3  Brand preferences, Price range, User-generated...
# 4  Brand preferences, Sustainable certifications,...
#
#               features_for_app.1
# 0            Discounts and sales
# 1            Discounts and sales
# 2            Discounts and sales
# 3     Athletic and modern fusion
# 4  Need more comfortable options
# Cleaned data saved to /Users/amelia/Documents/python_project/cleaned_python_project_final_edit.xlsx

# %% [markdown]
# ## Data Analysis

# %%
file_path = '/Users/amelia/Documents/python_project/cleaned_python_project_final_edit.xlsx'
df = pd.read_excel(file_path, sheet_name='Sheet1')

#Count Plot - Gender vs. Shopping Venues
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='gender', hue='shopping_venues', palette='viridis')
plt.title('Gender vs. Shopping Venues')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

#Bar Plot - Influence of Sustainability Labels by Age Group
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='age', y='influence_of_sustainability_labels', palette='viridis')
plt.title('Influence of Sustainability Labels by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Influence of Sustainability Labels')
plt.tight_layout()
plt.show()

# Bar plot - Occupation by Importance Of Sustainability
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='occupation', y='importance_of_sustainability', palette='viridis')
plt.title('Importance of Sustainability by Occupation')
plt.xlabel('Occupation')
plt.ylabel('Importance of Sustainability')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
